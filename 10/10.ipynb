# %% [markdown]
# **10.1**
#
#
# Aydin Reisiyan, Iman Rafiie, Alireza Roozbahani

# %% [markdown]
# \begin{equation}
# T_0=\frac {2\ sin\ ω \ T_1}{ω}|_ω=_\frac {2πk}{T_0}\\
# \end{equation}

# %% [markdown]
# **10.3**
#
#
# AmirAbbas Kaidi, Mehrdad Yaghoubi, Mostafa Shabani

# %% [markdown]
# x[n] = Acos (𝝮 + 𝜙)
#
# x[n] = x[n+N] smallest integar N ≜ period
#
# Acos [𝛀(n+N) + 𝜙]= Acos [𝝮n + 𝝮N + 𝜙]
#
#                         integer multiple of 2π?
# Periodic => 𝝮N = 2πm
#
# N = 2πm/𝛀
#
# N,m must be integers
#
# smallest N (if any) = period

# %% [markdown]
# Σay[n - k] = Σbx[n - k]
#
# Σay[n - k] = 0 (Homogeneous Equiation)
#
# ---
# If y[n] satisfies (1) then so does
#
# y[n] + y[n] where y[n] satifies (2)
#
# y[n] ≜ Particular solution
#
# y[n] ≜ Homogeneous solution

# %% [markdown]
# x(t) periodic , x(t) represents one period
#
# - Fourier coefficients of x(t)
#
#   = (1/T) times samples of Fourier trasform of x(t)
#
# ---
# x(t) PERIODIC
#
# - Fourier transform of x(t) defind as impulse train:
#
#      X(𝜔) ≜ Σ2πaδ(𝛚 - k𝛚)

# %%
import numpy as np
import matplotlib.pyplot as plt

def generate_plot(omega, theta=0, x1=0, x2=35):
    n = np.arange(x1, x2)
    x = np.sin((n + 1) * omega / 2) / np.sin(omega / 2)
    plt.figure(figsize=(6, 4))
    plt.stem(n, x, use_line_collection=True)
    plt.xlabel('$n$')
    plt.ylabel('$x[n]$')
    plt.gca().margins(y=0.1)

# Example usage
generate_plot(0.5)
plt.show()
# Out:
# <ipython-input-15-a55611cc49c6>:8: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(n, x, use_line_collection=True)

# %% [markdown]
# **10.4**
#
#
# Asal Rezazadeh, AmirMohammad GhahremanNezhad, Amirmohammad Montazeri

# %% [markdown]
# ### ***2.5)Lec10 - 10.4: Transparency***
#
#
# \begin{equation}
# Envelope = (sin[(2N₁+1)Ω/2])/sin(Ω/2)
# \end{equation}

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def f(x):
  return np.sin(41*x/2) / np.sin(x/2)

x = np.linspace (-10, 10, 1000)
y = f(x)

plt.plot(x, y)

plt.xlabel('x')
plt.ylabel('Envelope')
plt.show()

# %% [markdown]
# **10.9**
#
#
# Reza SobhaniAmirhossein KaramiAli Eshraghi

# %%
import numpy as np
import matplotlib.pyplot as plt

def step_function(x):
    """
    Computes the step function for an array of values.

    Parameters:
        x (ndarray): The input values.

    Returns:
        ndarray: The step function for the input values.
    """
    return np.where(x >= 0, 1, 0)

# Generate the input values
x = np.linspace(-3, 3, 15)

# Compute the step function for 5 cycles
y = []
for i in range(5):
    y.append(step_function(x))

# Flatten the resulting list of arrays
y = np.concatenate(y)

# Compute the DTFT
N = len(y)
w = np.linspace(-np.pi, np.pi, N, endpoint=False)
Y = np.fft.fftshift(np.fft.fft(y))

# Plot the results
plt.figure(figsize=(8, 6))
plt.subplot(2, 1, 1)
plt.stem(y)
plt.xlabel('n')
plt.ylabel('y[n]')
plt.title('Step Function ')

plt.subplot(2, 1, 2)
plt.plot(w, np.abs(Y))
plt.xlabel('Frequency (radians/sample)')
plt.ylabel('|Y(w)|')
plt.title('DTFT of Step Function ')
plt.tight_layout()
plt.show()
#Ali Eshraghi Amirhossein Karami Agha Reza Sobhani 10.9

# %% [markdown]
# **10.10**
#
#
# Diana Najmedin, Hasti Farsijani

# %% [markdown]
# 10.10

# %%
mu = sym.symbols('mu', integer=True)
t = sym.symbols('t', real=True)
T = 4
Tp = 8


def pulse_train(T, Tp):
    n = sym.symbols('n', integer=True)
    x0 = sym.Piecewise((0, t < 0), (0.5, t < T), (0, True))
    return sym.summation(x0.subs(t, t+n*Tp), (n, -10, 10))


sym.plot(pulse_train(T, Tp), (t, -10, 10), xlabel=r'$t$', ylabel=r'$x(t)$');

# %%
X_mu = sym.exp(-sym.I * mu * sym.pi * T/Tp) * T * sym.sinc(mu * sym.pi * T/Tp)
X_mu
# Out:
#    -2⋅ⅈ⋅π⋅μ
#    ─────────
#        5         ⎛2⋅π⋅μ⎞
# 2⋅ℯ         ⋅sinc⎜─────⎟
#                  ⎝  5  ⎠

# %%
import numpy as np
import matplotlib.pyplot as plt

Xn = sym.lambdify(mu, sym.Abs(X_mu), 'numpy')

n = np.arange(-15, 15)
plt.stem(n*2*np.pi/Tp, Xn(n))
plt.xlabel('$\omega$')
plt.ylabel('$|X(j \omega)|$');

# %% [markdown]
# **10.11**
#
#
# Hossein Karbalaii Hadi, Arshia Kord, Mohammadhossein Karami

# %%
import sympy as sp

t, T = sp.symbols('t T')
x = sp.Function('x')(t)

expr = sp.Integral(x.subs(t, t-T)*sp.DiracDelta(t-T), (t, -sp.oo, sp.oo))
sp.pprint(expr)


by:Karbalaee,Karami,Kord
# Out:
# ∞
# ⌠
# ⎮  x(-T + t)⋅δ(-T + t) dt
# ⌡
# -∞

# %% [markdown]
# **10.14**
#
#
# Mobin Salehi Nejad, Ali Gharloghi, Kiarash Kia

# %%
import matplotlib.pyplot as plt
import numpy as np

min_n_val = -100
max_n_val = 100

n = np.arange(min_n_val, max_n_val+1 , 1)
x_n = np.where(np.logical_and(n >= -2, n <= 2), 1.0, 0.0)

dft = np.fft.fft(x_n)

freqs = np.fft.fftfreq(len(n), 1)

plt.subplot(2, 1, 1)
plt.stem(n, x_n)
plt.xlabel('n')
plt.xlim(-10,10)
plt.ylabel('x_n')
plt.title('Rectangular Pulse')
plt.grid()

plt.subplot(2, 1, 2)
plt.plot(freqs, dft)
plt.xlabel('Ω')
#plt.xlim(-6,6)
plt.ylabel('X(Ω)')
plt.ylim(-5,5)
plt.title('Fourier Transform')
plt.grid()

plt.tight_layout()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# **10.20**
#
#
# Asal Rezazadeh, AmirMohammad GhahremanNezhad, Amirmohammad Montazeri

# %% [markdown]
# ### ***2.6)Lec10 - 10.20: Transparency***
#
#
# \begin{equation}
# Envelope = (sin[(2N₁+1)Ω/2])/sin(Ω/2)
# \end{equation}
