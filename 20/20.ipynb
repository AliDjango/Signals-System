# %% [markdown]
# **20.1**
#
#
# Diana Najmedin, Hasti Farsijani,

# %% [markdown]
# # **20.1**

# %% [markdown]
# \begin{equation}
# Properties\ of\ the\ region\ of\  converience\\ the\ ROC\ contains\ no\ poles\\
# x(s) = \frac{N(s)}{D(s)}\\poles\ of\ x(s) =>D(s) = 0\\ The\  ROC\ of\ X(s)\ consists\ of\ a\ strip\
# parallel\ to\ the\ jw-axis\ in\ the\ s-plane\\\mathcal{L} \{ x(t) \}\ converges\\<=>ROC\ includes\
# the\ jw-axis\ in\ the\ s-plane\
# \end{equation}

# %% [markdown]
# **20.2**
#
#
# Hossein Karbalaii Hadi, Arshia Kord, Mohammadhossein Karami

# %% [markdown]
# **20.8**
#
#
# Bahar Esmayili, Amir Bayati,

# %% [markdown]
# #20.8
# *x(t) left-sided and Re{s} = σ is in ROC => all values
#
# for wich Re{s} < * are in ROC
# *x(t) left-sided and X(s) rational => ROC to the left of the leftmost pole
#
#  * x(t) two-sided and Re{s} = σ is in ROC => ROC is a strip in the s-plane

# %% [markdown]
# **20.10**
#
#
# Aydin Reisiyan, Iman Rafiie, Alireza Roozbahani

# %% [markdown]
# \begin{equation}
# x(s) =\frac{1}{(s+1)(s+2)}\ \ \ Re\{s\}>-1\\=\frac{1}{(s+1)}-\frac{1}{(s+2)}\ \ \ Re \{s\}>-1
# \end{equation}

# %% [markdown]
# **20.11**
#
#
# Melika Amirpour, Samaneh MohammadMirzayi,

# %% [markdown]
# **20.11**
#
# ![Screenshot (204).png](data:image/png;base64,...)
# \begin{equation}
# X_2(s)=\frac{-1}{s+2} \  \   \  Re \ {s}>-1\\
# x_2(t)=-e^{-2t} u(t)\\
# \end{equation}
